# %% [markdown]
# # Please find below assignment questions:
#
# - Problem statement
# [31965,29296,33152,33408,33518,33513,33573,33588,33611,33632,33630,33633,33420,33647,12790,33662,33412,33649,33635,33673,33668,33669,33663,33628,33672,33645,33410,33638,33689,33685,33687,33688,33691,33692,33686,33690,33642,33700,33584,33417,33637,33676,33597,33693,33716,33742,33744,33714,33695,33751,33740,33780,33699,33794,33770,33741,33840,33771,33774,958,33839,33804,33882,33426,33979,33653,32202,14055,21439,34000,34098,31908,14041,34120,11788,34105,34074,32064,31914,34003,34110,34143,34121,34136,31233,34140,29299,31315,29295,34100,34106,14027,34194,34193,34180,34171,34189,34175,34182,34199,34198,34146,11694,34204,34229,34224,34149,32876,34205,34081,34185,34197,34209,34207,34221,27436,34131,34245,32504,11698]
#
# Take the above list as input.
#
# First, sort the list without using python inbuilt sort function.
# Then get the even numbers from the list.
# And reverse the list of even numbers without using the inbuilt reverse function.
#
# So there will be three outputs:
# - Sorted list.
# - List of even elements.
# - The reverse of the list.
#
# Assignments will mainly be focused on data analysis, list and dictionaries are the primary data types used in python.

# %%
number = [31965,29296,33152,33408,33518,33513,33573,33588,33611,33632,33630,33633,33420,33647,12790,33662,33412,33649,33635,33673,33668,33669,33663,33628,33672,33645,33410,33638,33689,33685,33687,33688,33691,33692,33686,33690,33642,33700,33584,33417,33637,33676,33597,33693,33716,33742,33744,33714,33695,33751,33740,33780,33699,33794,33770,33741,33840,33771,33774,958,33839,33804,33882,33426,33979,33653,32202,14055,21439,34000,34098,31908,14041,34120,11788,34105,34074,32064,31914,34003,34110,34143,34121,34136,31233,34140,29299,31315,29295,34100,34106,14027,34194,34193,34180,34171,34189,34175,34182,34199,34198,34146,11694,34204,34229,34224,34149,32876,34205,34081,34185,34197,34209,34207,34221,27436,34131,34245,32504,11698]
print(number)
print(len(number))
# Out:
# [31965, 29296, 33152, 33408, 33518, 33513, 33573, 33588, 33611, 33632, 33630, 33633, 33420, 33647, 12790, 33662, 33412, 33649, 33635, 33673, 33668, 33669, 33663, 33628, 33672, 33645, 33410, 33638, 33689, 33685, 33687, 33688, 33691, 33692, 33686, 33690, 33642, 33700, 33584, 33417, 33637, 33676, 33597, 33693, 33716, 33742, 33744, 33714, 33695, 33751, 33740, 33780, 33699, 33794, 33770, 33741, 33840, 33771, 33774, 958, 33839, 33804, 33882, 33426, 33979, 33653, 32202, 14055, 21439, 34000, 34098, 31908, 14041, 34120, 11788, 34105, 34074, 32064, 31914, 34003, 34110, 34143, 34121, 34136, 31233, 34140, 29299, 31315, 29295, 34100, 34106, 14027, 34194, 34193, 34180, 34171, 34189, 34175, 34182, 34199, 34198, 34146, 11694, 34204, 34229, 34224, 34149, 32876, 34205, 34081, 34185, 34197, 34209, 34207, 34221, 27436, 34131, 34245, 32504, 11698]
# 120

# %%
def ascendsort(n):
    for i in range(1, len(n)):
        j = i - 1
        next_n = n[i]
        while (n[j] > next_n) and (j >= 0):
            n[j+1] = n [j]
            j = j - 1
        n[j+1] = next_n
    print(n)
    
ascendsort(number)
# Out:
# [958, 11694, 11698, 11788, 12790, 14027, 14041, 14055, 21439, 27436, 29295, 29296, 29299, 31233, 31315, 31908, 31914, 31965, 32064, 32202, 32504, 32876, 33152, 33408, 33410, 33412, 33417, 33420, 33426, 33513, 33518, 33573, 33584, 33588, 33597, 33611, 33628, 33630, 33632, 33633, 33635, 33637, 33638, 33642, 33645, 33647, 33649, 33653, 33662, 33663, 33668, 33669, 33672, 33673, 33676, 33685, 33686, 33687, 33688, 33689, 33690, 33691, 33692, 33693, 33695, 33699, 33700, 33714, 33716, 33740, 33741, 33742, 33744, 33751, 33770, 33771, 33774, 33780, 33794, 33804, 33839, 33840, 33882, 33979, 34000, 34003, 34074, 34081, 34098, 34100, 34105, 34106, 34110, 34120, 34121, 34131, 34136, 34140, 34143, 34146, 34149, 34171, 34175, 34180, 34182, 34185, 34189, 34193, 34194, 34197, 34198, 34199, 34204, 34205, 34207, 34209, 34221, 34224, 34229, 34245]

# %%
even = []
odd = []
for e in number:
    if(e % 2 == 0):
        even.append(e)
    else:
        odd.append(e)
        
print(even)
# Out:
# [958, 11694, 11698, 11788, 12790, 27436, 29296, 31908, 31914, 32064, 32202, 32504, 32876, 33152, 33408, 33410, 33412, 33420, 33426, 33518, 33584, 33588, 33628, 33630, 33632, 33638, 33642, 33662, 33668, 33672, 33676, 33686, 33688, 33690, 33692, 33700, 33714, 33716, 33740, 33742, 33744, 33770, 33774, 33780, 33794, 33804, 33840, 33882, 34000, 34074, 34098, 34100, 34106, 34110, 34120, 34136, 34140, 34146, 34180, 34182, 34194, 34198, 34204, 34224]

# %%
def descendsort(n):
    for i in range(1, len(n)):
        j = i - 1
        next_n = n[i]
        while (n[j] < next_n) and (j >= 0):
            n[j+1] = n [j]
            j = j - 1
        n[j+1] = next_n
    print(n)

descendsort(even)
# Out:
# [34224, 34204, 34198, 34194, 34182, 34180, 34146, 34140, 34136, 34120, 34110, 34106, 34100, 34098, 34074, 34000, 33882, 33840, 33804, 33794, 33780, 33774, 33770, 33744, 33742, 33740, 33716, 33714, 33700, 33692, 33690, 33688, 33686, 33676, 33672, 33668, 33662, 33642, 33638, 33632, 33630, 33628, 33588, 33584, 33518, 33426, 33420, 33412, 33410, 33408, 33152, 32876, 32504, 32202, 32064, 31914, 31908, 29296, 27436, 12790, 11788, 11698, 11694, 958]
